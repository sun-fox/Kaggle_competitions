# %%
import pandas as pd

# %%
train = pd.read_table("train.csv",sep=",")
train
# Out:
#          RMSD        F1       F2       F3        F4            F5        F6  \
# 0      17.284  13558.30  4305.35  0.31754  162.1730  1.872791e+06  215.3590
# 1       6.021   6191.96  1623.16  0.26213   53.3894  8.034467e+05   87.2024
# 2       9.275   7725.98  1726.28  0.22343   67.2887  1.075648e+06   81.7913
# 3      15.851   8424.58  2368.25  0.28111   67.8325  1.210472e+06  109.4390
# 4       7.962   7460.84  1736.94  0.23280   52.4123  1.021020e+06   94.5234
# ...       ...       ...      ...      ...       ...           ...       ...
# 29996   2.591   9257.79  2768.73  0.29907   91.3902  1.313740e+06  123.4960
# 29997   1.034   9402.79  1804.98  0.19196  107.6270  1.335660e+06  123.4660
# 29998   1.428  15127.00  4397.50  0.29070  211.2770  2.117603e+06  248.1870
# 29999  20.754  18415.20  7557.31  0.41038  209.9870  2.474283e+06  333.6490
# 30000   6.230  13723.40  5168.99  0.37665  157.2620  1.899948e+06  196.6510
#
#             F7   F8       F9
# 0      4287.87  102  27.0302
# 1      3328.91   39  38.5468
# 2      2981.04   29  38.8119
# 3      3248.22   70  39.0651
# 4      2814.42   41  39.9147
# ...        ...  ...      ...
# 29996  3368.21   14  36.7691
# 29997  4194.61   49  34.0800
# 29998  5332.01  294  24.2649
# 29999  5825.95  198  29.2394
# 30000  5256.69   46  27.5428
#
# [30001 rows x 10 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
train.describe()
# Out:
#                RMSD            F1            F2            F3            F4  \
# count  30001.000000  30001.000000  30001.000000  30001.000000  30001.000000
# mean       7.697942   9851.588091   3003.787161      0.301801    103.299843
# std        6.087291   4042.792773   1451.928534      0.062803     55.436934
# min        0.000000   2783.150000    403.500000      0.092500     10.689100
# 25%        2.299000   6941.190000   1975.960000      0.258210     63.521700
# 50%        4.976000   8875.290000   2659.680000      0.299460     87.432600
# 75%       13.294000  12077.800000   3766.820000      0.341980    133.425000
# max       20.999000  38042.200000  15312.000000      0.577690    369.317000
#
#                  F5            F6             F7            F8            F9
# count  3.000100e+04  30001.000000   30001.000000  30001.000000  30001.000000
# mean   1.365474e+06    145.249444    3986.213546     69.960868     34.539666
# std    5.618971e+05     69.850407    2030.130189     56.462140      5.966959
# min    3.743155e+05     31.970400    1089.190000      0.000000     15.228000
# 25%    9.534198e+05     94.740400    3166.130000     31.000000     30.505600
# 50%    1.235293e+06    125.918000    3837.700000     54.000000     35.293200
# 75%    1.683858e+06    180.731000    4635.960000     91.000000     38.869500
# max    5.050786e+06    594.790000  105948.170000    348.000000     48.202800

# %%
Y = train.RMSD
X = train.drop(['RMSD'],axis=1)

import matplotlib.pyplot as plt
plt.plot(X,train.RMSD)
plt.xlabel('X-axis')
plt.ylabel('RMSD')
# Out:
# Text(0, 0.5, 'RMSD')

# %%
lr = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
lr.fit(X,Y)
tst = pd.read_csv("test.csv")

# %%
print(lr)
tst
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#              F1        F2       F3        F4            F5        F6       F7  \
# 0       4101.34   1041.57  0.25395   32.5808  5.725388e+05   44.3736  1766.01
# 1       9899.12   2450.54  0.24755  115.6450  1.382614e+06  133.2660  4205.80
# 2       8382.20   3001.85  0.35812   66.6010  1.205820e+06  115.5440  3320.56
# 3       8134.14   4272.91  0.52530   86.2275  1.152265e+06  145.2760  3589.45
# 4      31821.80  10979.00  0.34501  271.1200  4.364453e+06  426.2930  7628.83
# ...         ...       ...      ...       ...           ...       ...      ...
# 15724   8037.12   2777.68  0.34560   64.3390  1.105797e+06  112.7460  3384.21
# 15725   7978.76   2508.57  0.31440   75.8654  1.116725e+06  102.2770  3974.52
# 15726   7726.65   2489.58  0.32220   70.9903  1.076560e+06  103.6780  3290.46
# 15727   8878.93   3055.78  0.34416   94.0314  1.242266e+06  115.1950  3421.79
# 15728  12732.40   4444.36  0.34905  157.6300  1.788897e+06  229.4590  4626.85
#
#         F8       F9
# 0       33  44.0469
# 1       71  34.5281
# 2       89  37.2830
# 3       53  35.9908
# 4      200  46.5464
# ...    ...      ...
# 15724   84  36.8036
# 15725   54  36.0470
# 15726   46  37.4718
# 15727   41  35.6045
# 15728  141  29.8118
#
# [15729 rows x 9 columns]

# %%
X
# Out:
#              F1       F2       F3        F4            F5        F6       F7  \
# 0      13558.30  4305.35  0.31754  162.1730  1.872791e+06  215.3590  4287.87
# 1       6191.96  1623.16  0.26213   53.3894  8.034467e+05   87.2024  3328.91
# 2       7725.98  1726.28  0.22343   67.2887  1.075648e+06   81.7913  2981.04
# 3       8424.58  2368.25  0.28111   67.8325  1.210472e+06  109.4390  3248.22
# 4       7460.84  1736.94  0.23280   52.4123  1.021020e+06   94.5234  2814.42
# ...         ...      ...      ...       ...           ...       ...      ...
# 29996   9257.79  2768.73  0.29907   91.3902  1.313740e+06  123.4960  3368.21
# 29997   9402.79  1804.98  0.19196  107.6270  1.335660e+06  123.4660  4194.61
# 29998  15127.00  4397.50  0.29070  211.2770  2.117603e+06  248.1870  5332.01
# 29999  18415.20  7557.31  0.41038  209.9870  2.474283e+06  333.6490  5825.95
# 30000  13723.40  5168.99  0.37665  157.2620  1.899948e+06  196.6510  5256.69
#
#         F8       F9
# 0      102  27.0302
# 1       39  38.5468
# 2       29  38.8119
# 3       70  39.0651
# 4       41  39.9147
# ...    ...      ...
# 29996   14  36.7691
# 29997   49  34.0800
# 29998  294  24.2649
# 29999  198  29.2394
# 30000   46  27.5428
#
# [30001 rows x 9 columns]

# %%
ans = lr.predict(tst)

# %%
ans
# Out:
# array([ 7.03092   ,  4.8901728 , 11.70949791, ...,  9.09123949,
#         8.78277109,  6.87764428])

# %%
Y
# Out:
# 0        17.284
# 1         6.021
# 2         9.275
# 3        15.851
# 4         7.962
#           ...
# 29996     2.591
# 29997     1.034
# 29998     1.428
# 29999    20.754
# 30000     6.230
# Name: RMSD, Length: 30001, dtype: float64

# %%
from sklearn.metrics import r2_score
score=r2_score(train.RMSD,ans)

# %%
print(score)
# Out:
# 0.27996250474300677
